# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
df = pd.read_csv('tmdb-movies.csv')
df.head(1)
# Out:
#        id    imdb_id  popularity     budget     revenue  original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#                         homepage         director            tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow  The park is open.  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
#
# [1 rows x 21 columns]

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df_budget_zero = df.query('budget == 0')
df_budget_zero.head(3)
# Out:
#         id    imdb_id  popularity  budget   revenue    original_title  \
# 30  280996  tt3168230    3.927333       0  29355203        Mr. Holmes
# 36  339527  tt1291570    3.358321       0  22354572            Solace
# 72  284289  tt2911668    2.272044       0     45895  Beyond the Reach
#
#                                                  cast  \
# 30  Ian McKellen|Milo Parker|Laura Linney|Hattie M...
# 36  Abbie Cornish|Jeffrey Dean Morgan|Colin Farrel...
# 72  Michael Douglas|Jeremy Irvine|Hanna Mangan Law...
#
#                         homepage                 director  \
# 30  http://www.mrholmesfilm.com/              Bill Condon
# 36                           NaN            Afonso Poyart
# 72                           NaN  Jean-Baptiste L̩onetti
#
#                                               tagline  ...  \
# 30                            The man behind the myth  ...
# 36  A serial killer who can see your future, a psy...  ...
# ...

# %%
df_revenue_zero = df.query('revenue == 0')
df_revenue_zero.head(3)
# Out:
#         id    imdb_id  popularity    budget  revenue          original_title  \
# 48  265208  tt2231253    2.932340  30000000        0               Wild Card
# 67  334074  tt3247714    2.331636  20000000        0                Survivor
# 74  347096  tt3478232    2.165433         0        0  Mythica: The Darkspore
#
#                                                  cast  \
# 48  Jason Statham|Michael Angarano|Milo Ventimigli...
# 67  Pierce Brosnan|Milla Jovovich|Dylan McDermott|...
# 74  Melanie Stone|Kevin Sorbo|Adam Johnson|Jake St...
#
#                                      homepage        director  \
# 48                                        NaN      Simon West
# 67                  http://survivormovie.com/  James McTeigue
# 74  http://www.mythicamovie.com/#!blank/wufvh   Anne K. Black
#
#                                         tagline  ...  \
# 48  Never bet against a man with a killer hand.  ...
# 67           His Next Target is Now Hunting Him  ...
# ...

# %%
df_budget_0count= df.groupby('budget').count()['id']

# %%
df_budget_0count.head(2)
# Out:
# budget
# 0    5696
# 1       4
# Name: id, dtype: int64

# %%
df_revenue_0count= df.groupby('revenue').count()['id']
df_revenue_0count.head(2)
# Out:
# revenue
# 0    6016
# 2       2
# Name: id, dtype: int64

# %%
df_runtime_0count = df.groupby('runtime').count()['id']

# %%
df_runtime_0count.head(2)
# Out:
# runtime
# 0    31
# 2     5
# Name: id, dtype: int64

# %%
col = ['imdb_id', 'homepage', 'tagline', 'overview', 'budget_adj', 'revenue_adj']
df.drop(col, axis=1, inplace=True)

# %%
df.head(1)
# Out:
#        id  popularity     budget     revenue  original_title  \
# 0  135397   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
#
#                                             keywords  runtime  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island      124
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
#
#    vote_average  release_year
# 0           6.5          2015

# %%
df.drop_duplicates(inplace=True)

# %%
col2 = ['cast','director','genres']
df.dropna(subset=col2, how='any', inplace=True)

# %%
df.isnull().sum()
# Out:
# id                         0
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                       0
# director                   0
# keywords                1425
# runtime                    0
# genres                     0
# production_companies     959
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# dtype: int64

# %%
df['budget']=df['budget'].replace(0, np.NaN)
df['revenue']=df['revenue'].replace(0, np.NaN)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10731 entries, 0 to 10865
# Data columns (total 15 columns):
# id                      10731 non-null int64
# popularity              10731 non-null float64
# budget                  5153 non-null float64
# revenue                 4843 non-null float64
# original_title          10731 non-null object
# cast                    10731 non-null object
# director                10731 non-null object
# keywords                9306 non-null object
# runtime                 10731 non-null int64
# genres                  10731 non-null object
# production_companies    9772 non-null object
# release_date            10731 non-null object
# vote_count              10731 non-null int64
# vote_average            10731 non-null float64
# release_year            10731 non-null int64
# dtypes: float64(4), int64(4), object(7)
# memory usage: 1.3+ MB

# %%
df.query('runtime != 0', inplace=True)
df.query('runtime == 0')
# Out:
# Empty DataFrame
# Columns: [id, popularity, budget, revenue, original_title, cast, director, keywords, runtime, genres, production_companies, release_date, vote_count, vote_average, release_year]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10703 entries, 0 to 10865
# Data columns (total 15 columns):
# id                      10703 non-null int64
# popularity              10703 non-null float64
# budget                  5150 non-null float64
# revenue                 4843 non-null float64
# original_title          10703 non-null object
# cast                    10703 non-null object
# director                10703 non-null object
# keywords                9293 non-null object
# runtime                 10703 non-null int64
# genres                  10703 non-null object
# production_companies    9759 non-null object
# release_date            10703 non-null object
# vote_count              10703 non-null int64
# vote_average            10703 non-null float64
# release_year            10703 non-null int64
# dtypes: float64(4), int64(4), object(7)
# memory usage: 1.3+ MB

# %%
df.head(5)
# Out:
#        id  popularity       budget       revenue  \
# 0  135397   32.985763  150000000.0  1.513529e+09
# 1   76341   28.419936  150000000.0  3.784364e+08
# 2  262500   13.112507  110000000.0  2.952382e+08
# 3  140607   11.173104  200000000.0  2.068178e+09
# 4  168259    9.335014  190000000.0  1.506249e+09
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
# ...

# %%
df_2000_2005 = df[(df.release_year >= 2000) & (df.release_year <= 2005)]

# %%
df_2000_2005.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1672 entries, 2633 to 8887
# Data columns (total 15 columns):
# id                      1672 non-null int64
# popularity              1672 non-null float64
# budget                  993 non-null float64
# revenue                 864 non-null float64
# original_title          1672 non-null object
# cast                    1672 non-null object
# director                1672 non-null object
# keywords                1482 non-null object
# runtime                 1672 non-null int64
# genres                  1672 non-null object
# production_companies    1479 non-null object
# release_date            1672 non-null object
# vote_count              1672 non-null int64
# vote_average            1672 non-null float64
# release_year            1672 non-null int64
# dtypes: float64(4), int64(4), object(7)
# memory usage: 209.0+ KB

# %%
df_2000_2005.head(5)
# Out:
#         id  popularity       budget      revenue  \
# 2633   120    8.575419   93000000.0  871368364.0
# 2634   671    8.021423  125000000.0  976475550.0
# 2635  1018    4.436367   15000000.0   20117339.0
# 2636   141    3.851009    6000000.0    1270522.0
# 2637   585    3.204295  115000000.0  562816256.0
#
#                                          original_title  \
# 2633  The Lord of the Rings: The Fellowship of the Ring
# 2634           Harry Potter and the Philosopher's Stone
# 2635                                   Mulholland Drive
# 2636                                       Donnie Darko
# 2637                                     Monsters, Inc.
#
#                                                    cast  \
# 2633  Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...
# 2634  Daniel Radcliffe|Rupert Grint|Emma Watson|John...
# 2635  Naomi Watts|Laura Harring|Ann Miller|Dan Heday...
# 2636  Jake Gyllenhaal|Patrick Swayze|Drew Barrymore|...
# ...

# %%
df.query('release_year==2000')
# Out:
#          id  popularity       budget      revenue  \
# 8661     98    4.271452  103000000.0  457640427.0
# 8662     77    3.095625    9000000.0   39723096.0
# 8663   8871    2.977558  123000000.0  345141403.0
# 8664   8358    2.197205   90000000.0  429632142.0
# 8665    107    2.153361   10000000.0   83557872.0
# ...     ...         ...          ...          ...
# 8883  36047    0.015997   15000000.0    5217498.0
# 8884  97351    0.006865          NaN          NaN
# 8885  20438    0.005784          NaN          NaN
# 8886  18292    0.080819          NaN          NaN
# 8887  44756    0.004010          NaN          NaN
#
#                       original_title  \
# 8661                       Gladiator
# 8662                         Memento
# 8663  How the Grinch Stole Christmas
# 8664                       Cast Away
# 8665                          Snatch
# ...                              ...
# 8883                    The In Crowd
# 8884     Phir Bhi Dil Hai Hindustani
# ...

# %%
df_2000_2005.tail(5)
# Out:
#          id  popularity      budget    revenue               original_title  \
# 8883  36047    0.015997  15000000.0  5217498.0                 The In Crowd
# 8884  97351    0.006865         NaN        NaN  Phir Bhi Dil Hai Hindustani
# 8885  20438    0.005784         NaN        NaN             The Tao of Steve
# 8886  18292    0.080819         NaN        NaN            George Washington
# 8887  44756    0.004010         NaN        NaN              Is It Fall Yet?
#
#                                                    cast  \
# 8883  Susan Ward|Lori Heuring|Matthew Settle|Nathan ...
# 8884  Juhi Chawla|Shah Rukh Khan|Johnny Lever|Shakti...
# 8885  Donal Logue|Ayelet Kaznelson|John Hines|John H...
# 8886  Candace Evanofski|Donald Holden|Damian Jewan L...
# 8887                      Tracy Grandstaff|Wendy Hoopes
#
#                     director               keywords  runtime  \
# 8883            Mary Lambert         woman director      105
# ...

# %%
df_2000_2005.head(5)
# Out:
#         id  popularity       budget      revenue  \
# 2633   120    8.575419   93000000.0  871368364.0
# 2634   671    8.021423  125000000.0  976475550.0
# 2635  1018    4.436367   15000000.0   20117339.0
# 2636   141    3.851009    6000000.0    1270522.0
# 2637   585    3.204295  115000000.0  562816256.0
#
#                                          original_title  \
# 2633  The Lord of the Rings: The Fellowship of the Ring
# 2634           Harry Potter and the Philosopher's Stone
# 2635                                   Mulholland Drive
# 2636                                       Donnie Darko
# 2637                                     Monsters, Inc.
#
#                                                    cast  \
# 2633  Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...
# 2634  Daniel Radcliffe|Rupert Grint|Emma Watson|John...
# 2635  Naomi Watts|Laura Harring|Ann Miller|Dan Heday...
# 2636  Jake Gyllenhaal|Patrick Swayze|Drew Barrymore|...
# ...

# %%
df_2000_2005.sort_values(['release_year'],ascending=True)
# Out:
#          id  popularity      budget      revenue   original_title  \
# 8887  44756    0.004010         NaN          NaN  Is It Fall Yet?
# 8739   2155    0.525341  42000000.0   32168970.0   Reindeer Games
# 8738  11678    0.530739  75000000.0  215663859.0   Vertical Limit
# 8737  10429    0.533792         NaN          NaN         Takedown
# 8736   4234    0.542611  40000000.0  161834276.0         Scream 3
# ...     ...         ...         ...          ...              ...
# 6434   6473    0.376497         NaN          NaN     The Marksman
# 6435   2610    0.270403  10284523.0   11588205.0         Shopgirl
# 6436  19495    0.270053  25000000.0          NaN            Nomad
# 6416  35320    0.300101         NaN          NaN   School Of Life
# 6242   9621    1.083790  57000000.0   52034889.0    Elizabethtown
#
#                                                    cast  \
# 8887                      Tracy Grandstaff|Wendy Hoopes
# 8739  Ben Affleck|Gary Sinise|Charlize Theron|Dennis...
# ...

# %%
df_2000_2005 = df_2000_2005.sort_values(['release_year'],ascending=True)

# %%
df_2000_2005.head(5)
# Out:
#          id  popularity      budget      revenue   original_title  \
# 8887  44756    0.004010         NaN          NaN  Is It Fall Yet?
# 8739   2155    0.525341  42000000.0   32168970.0   Reindeer Games
# 8738  11678    0.530739  75000000.0  215663859.0   Vertical Limit
# 8737  10429    0.533792         NaN          NaN         Takedown
# 8736   4234    0.542611  40000000.0  161834276.0         Scream 3
#
#                                                    cast  \
# 8887                      Tracy Grandstaff|Wendy Hoopes
# 8739  Ben Affleck|Gary Sinise|Charlize Theron|Dennis...
# 8738  Chris O'Donnell|Robin Tunney|Bill Paxton|Scott...
# 8737  Skeet Ulrich|Angela Featherstone|Donal Logue|C...
# 8736  David Arquette|Neve Campbell|Courteney Cox|Pat...
#
#                     director  \
# 8887  Karen Disher|Guy Moore
# 8739      John Frankenheimer
# 8738         Martin Campbell
# 8737           Joe Chappelle
# 8736              Wes Craven
#
# ...

# %%
df_2000_2005['profit'] = df['revenue'] - df['budget']

# %%
df_2000_2005.head(5)
# Out:
#          id  popularity      budget      revenue   original_title  \
# 8887  44756    0.004010         NaN          NaN  Is It Fall Yet?
# 8739   2155    0.525341  42000000.0   32168970.0   Reindeer Games
# 8738  11678    0.530739  75000000.0  215663859.0   Vertical Limit
# 8737  10429    0.533792         NaN          NaN         Takedown
# 8736   4234    0.542611  40000000.0  161834276.0         Scream 3
#
#                                                    cast  \
# 8887                      Tracy Grandstaff|Wendy Hoopes
# 8739  Ben Affleck|Gary Sinise|Charlize Theron|Dennis...
# 8738  Chris O'Donnell|Robin Tunney|Bill Paxton|Scott...
# 8737  Skeet Ulrich|Angela Featherstone|Donal Logue|C...
# 8736  David Arquette|Neve Campbell|Courteney Cox|Pat...
#
#                     director  \
# 8887  Karen Disher|Guy Moore
# 8739      John Frankenheimer
# 8738         Martin Campbell
# 8737           Joe Chappelle
# 8736              Wes Craven
#
# ...

# %%
df_2000_2005_profit = df_2000_2005.sort_values(['profit'],ascending=False)

# %%
df_2000_2005_profit.head(5)
# Out:
#        id  popularity       budget       revenue  \
# 4949  122    7.122455   94000000.0  1.118889e+09
# 2634  671    8.021423  125000000.0  9.764756e+08
# 3911  121    8.095275   79000000.0  9.262874e+08
# 2633  120    8.575419   93000000.0  8.713684e+08
# 3912  672    6.012584  100000000.0  8.766885e+08
#
#                                          original_title  \
# 4949      The Lord of the Rings: The Return of the King
# 2634           Harry Potter and the Philosopher's Stone
# 3911              The Lord of the Rings: The Two Towers
# 2633  The Lord of the Rings: The Fellowship of the Ring
# 3912            Harry Potter and the Chamber of Secrets
#
#                                                    cast        director  \
# 4949  Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...   Peter Jackson
# 2634  Daniel Radcliffe|Rupert Grint|Emma Watson|John...  Chris Columbus
# 3911  Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...   Peter Jackson
# ...

# %%
df.sort_values(['budget'],ascending=True)
# Out:
#            id  popularity  budget  revenue  \
# 3581    59296    0.520430     1.0   1378.0
# 3065    12689    0.472691     1.0      NaN
# 1151   287524    0.177102     1.0      NaN
# 2618    39964    0.090186     1.0    100.0
# 8944    14373    0.464188     2.0     16.0
# ...       ...         ...     ...      ...
# 10860    5060    0.087034     NaN      NaN
# 10861      21    0.080598     NaN      NaN
# 10862   20379    0.065543     NaN      NaN
# 10863   39768    0.065141     NaN      NaN
# 10864   21449    0.064317     NaN      NaN
#
#                            original_title  \
# 3581              Love, Wedding, Marriage
# 3065   Angus, Thongs and Perfect Snogging
# 1151                          Fear Clinic
# 2618                         Lost & Found
# 8944                         Death Wish 2
# ...                                   ...
# 10860                 Carry On Screaming!
# 10861                  The Endless Summer
# 10862                          Grand Prix
# ...

# %%
df.sort_values(['budget'],ascending=False)
# Out:
#           id  popularity       budget       revenue  \
# 2244   46528    0.250540  425000000.0  1.108757e+07
# 3375    1865    4.955130  380000000.0  1.021683e+09
# 7387     285    4.965391  300000000.0  9.610000e+08
# 14     99861    5.944927  280000000.0  1.405036e+09
# 6570    1452    1.957331  270000000.0  3.910812e+08
# ...      ...         ...          ...           ...
# 10860   5060    0.087034          NaN           NaN
# 10861     21    0.080598          NaN           NaN
# 10862  20379    0.065543          NaN           NaN
# 10863  39768    0.065141          NaN           NaN
# 10864  21449    0.064317          NaN           NaN
#
#                                     original_title  \
# 2244                             The Warrior's Way
# 3375   Pirates of the Caribbean: On Stranger Tides
# 7387      Pirates of the Caribbean: At World's End
# 14                         Avengers: Age of Ultron
# 6570                              Superman Returns
# ...

# %%
df.sort_values(['revenue'],ascending=False)
# Out:
#            id  popularity       budget       revenue  \
# 1386    19995    9.432768  237000000.0  2.781506e+09
# 3      140607   11.173104  200000000.0  2.068178e+09
# 5231      597    4.355219  200000000.0  1.845034e+09
# 4361    24428    7.637767  220000000.0  1.519558e+09
# 0      135397   32.985763  150000000.0  1.513529e+09
# ...       ...         ...          ...           ...
# 10861      21    0.080598          NaN           NaN
# 10862   20379    0.065543          NaN           NaN
# 10863   39768    0.065141          NaN           NaN
# 10864   21449    0.064317          NaN           NaN
# 10865   22293    0.035919      19000.0           NaN
#
#                      original_title  \
# 1386                         Avatar
# 3      Star Wars: The Force Awakens
# 5231                        Titanic
# 4361                   The Avengers
# 0                    Jurassic World
# ...                             ...
# 10861            The Endless Summer
# ...

# %%
df.sort_values(['revenue'],ascending=True)
# Out:
#           id  popularity     budget  revenue                  original_title  \
# 5067   13537    0.462609  6000000.0      2.0                 Shattered Glass
# 8142    2293    0.552091  6000000.0      2.0                        Mallrats
# 1380   18196    0.097126        NaN      3.0                    The Sentinel
# 10607  12101    0.621476        NaN      3.0                   Soylent Green
# 3239   14301    0.352054   200000.0      3.0  Dr. Horrible's Sing-Along Blog
# ...      ...         ...        ...      ...                             ...
# 10861     21    0.080598        NaN      NaN              The Endless Summer
# 10862  20379    0.065543        NaN      NaN                      Grand Prix
# 10863  39768    0.065141        NaN      NaN             Beregis Avtomobilya
# 10864  21449    0.064317        NaN      NaN          What's Up, Tiger Lily?
# 10865  22293    0.035919    19000.0      NaN        Manos: The Hands of Fate
#
# ...

# %%
df_2000 = df[(df.release_year == 2000)]

# %%
df_2000.head(3)
# Out:
#         id  popularity       budget      revenue  \
# 8661    98    4.271452  103000000.0  457640427.0
# 8662    77    3.095625    9000000.0   39723096.0
# 8663  8871    2.977558  123000000.0  345141403.0
#
#                       original_title  \
# 8661                       Gladiator
# 8662                         Memento
# 8663  How the Grinch Stole Christmas
#
#                                                    cast           director  \
# 8661  Russell Crowe|Joaquin Phoenix|Connie Nielsen|O...       Ridley Scott
# 8662  Guy Pearce|Carrie-Anne Moss|Joe Pantoliano|Mar...  Christopher Nolan
# 8663  Jim Carrey|Taylor Momsen|Jeffrey Tambor|Christ...         Ron Howard
#
#                                                keywords  runtime  \
# 8661    rome|gladiator|roman empire|slavery|battlefield      155
# 8662         individual|insulin|tattoo|waitress|amnesia      113
# 8663  holiday|christmas party|new love|santa claus|v...      104
#
#                       genres  \
# ...

# %%
df_2000['runtime'].mean()
# Out:
# 105.08968609865471
